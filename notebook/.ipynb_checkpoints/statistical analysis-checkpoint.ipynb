# %%
import os
import sys
notebook_dir = os.path.dirname(os.path.abspath("__file__"))
project_dir = os.path.dirname(notebook_dir)

if project_dir not in sys.path:
    sys.path.append(project_dir)

import pandas as pd
import numpy as np

# %%
all_fighter_cluster = pd.read_csv(r"https://raw.githubusercontent.com/john-adeojo/ufc_styles/main/data/02_intermediate/all_fighter_clusters.csv")
fighter_data = pd.read_csv(r"https://github.com/john-adeojo/ufc_styles/blob/main/data/02_intermediate/fighter_data.csv?raw=true")
# all_fighter_cluster.drop(columns='Unnamed: 0', inplace=True)

# %%
analysis_data_base = fighter_data.merge(right=all_fighter_cluster[['cluster','specific_cluster', 'Fighter_dims', 'weight_class']], how='left', left_on=['Fighter_dims', 'weight_class'], right_on=['Fighter_dims', 'weight_class'])
analysis_data_base = analysis_data_base.dropna(subset=['cluster'])
analysis_data_opp = analysis_data_base.copy()
analysis_data_opp['opp_specific_cluster'] = analysis_data_opp['specific_cluster']
analysis_data = analysis_data_base.merge(right=analysis_data_opp[['weight_class', 'Fighter_dims', 'date', 'opp_specific_cluster']], how='inner', left_on=['weight_class', 'Opponent', 'date'], right_on=['weight_class', 'Fighter_dims', 'date'] )
analysis_data_opposing_styles = analysis_data.loc[analysis_data['opp_specific_cluster'] != analysis_data['specific_cluster']].copy()
analysis_data_opposing_styles = analysis_data_opposing_styles.loc[analysis_data_opposing_styles['cluster'] != -1]
# Out:
#                   R_fighter       B_fighter        date Winner  \
# 4           Arman Tsarukyan  Mateusz Gamrot  2022-06-25   Blue
# 6     Shayilan Nuerdanbieke        TJ Brown  2022-06-25    Red
# 9                   JP Buys     Cody Durden  2022-06-25   Blue
# 16          Joaquin Buckley   Albert Duraev  2022-06-18    Red
# 18              Court McGee  Jeremiah Wells  2022-06-18   Blue
# ...                     ...             ...         ...    ...
# 8589          Chuck Liddell   Vitor Belfort  2002-06-22    Red
# 8593            Jens Pulver         BJ Penn  2002-01-11    Red
# 8594                BJ Penn        Caol Uno  2001-11-02    Red
# 8595          Matt Lindland     Phil Baroni  2001-11-02    Red
# 8596            Jens Pulver  Dennis Hallman  2001-09-28    Red
#
#           weight_class    avg_KD  avg_opp_KD  avg_SUB_ATT  avg_opp_SUB_ATT  \
# 4          Lightweight  0.000291    0.000291     0.000582         0.000000
# 6        Featherweight  0.000000    0.000293     0.002053         0.001027
# 9            Flyweight  0.000000    0.001278     0.000319         0.001917
# 16        Middleweight  0.000000    0.001111     0.001111         0.000000
# 18        Welterweight  0.001645    0.000000     0.001645         0.001645
# ...                ...       ...         ...          ...              ...
# 8589  LightHeavyweight  0.000487    0.000000     0.000000         0.000061
# 8593       Lightweight  0.000103    0.000000     0.000488         0.001233
# 8594       Lightweight  0.002179    0.000000     0.000000         0.000000
# 8595      Middleweight  0.000000    0.000000     0.000000         0.000000
# 8596       Lightweight  0.000268    0.000000     0.000201         0.000000
#
#        avg_REV  ...  Stance_Southpaw  Stance_Switch  Stance_nan  \
# 4     0.000000  ...              1.0            0.0         0.0
# 6     0.001173  ...              0.0            1.0         0.0
# 9     0.000000  ...              1.0            0.0         0.0
# 16    0.000000  ...              0.0            0.0         0.0
# 18    0.000000  ...              0.0            1.0         0.0
# ...        ...  ...              ...            ...         ...
# 8589  0.000020  ...              0.0            0.0         0.0
# 8593  0.000051  ...              1.0            0.0         0.0
# 8594  0.000000  ...              0.0            0.0         0.0
# 8595  0.000000  ...              1.0            0.0         0.0
# 8596  0.000134  ...              1.0            0.0         0.0
#
#              fighter  method  fighter_result  cluster    specific_cluster  \
# 4     Mateusz Gamrot   U-DEC    Win by U-DEC      0.0       0_Lightweight
# 6           TJ Brown   U-DEC   Loss by U-DEC      1.0     1_Featherweight
# 9        Cody Durden  KO/TKO   Win by KO/TKO      1.0         1_Flyweight
# 16     Albert Duraev  KO/TKO  Loss by KO/TKO      1.0      1_Middleweight
# 18    Jeremiah Wells  KO/TKO   Win by KO/TKO      1.0      1_Welterweight
# ...              ...     ...             ...      ...                 ...
# 8589   Chuck Liddell   U-DEC    Win by U-DEC      1.0  1_LightHeavyweight
# 8593     Jens Pulver   M-DEC    Win by M-DEC      0.0       0_Lightweight
# 8594         BJ Penn  KO/TKO   Win by KO/TKO      1.0       1_Lightweight
# 8595   Matt Lindland   M-DEC    Win by M-DEC      0.0      0_Middleweight
# 8596     Jens Pulver   U-DEC    Win by U-DEC      0.0       0_Lightweight
#
#              Fighter_dims_y  opp_specific_cluster
# 4           Arman Tsarukyan         1_Lightweight
# 6     Shayilan Nuerdanbieke       2_Featherweight
# 9                   JP Buys           0_Flyweight
# 16          Joaquin Buckley        0_Middleweight
# 18              Court McGee        2_Welterweight
# ...                     ...                   ...
# 8589          Vitor Belfort    0_LightHeavyweight
# 8593                BJ Penn         1_Lightweight
# 8594               Caol Uno         0_Lightweight
# 8595            Phil Baroni        1_Middleweight
# 8596         Dennis Hallman         1_Lightweight
#
# [3010 rows x 84 columns]

# %%
analysis_data_opposing_styles = analysis_data_opposing_styles.loc[analysis_data_opposing_styles['corner'] == 'Red'].copy()
analysis_data_opposing_styles
# Out:
#                   R_fighter       B_fighter        date Winner  \
# 4306        Arman Tsarukyan  Mateusz Gamrot  2022-06-25   Blue
# 4308  Shayilan Nuerdanbieke        TJ Brown  2022-06-25    Red
# 4311                JP Buys     Cody Durden  2022-06-25   Blue
# 4318        Joaquin Buckley   Albert Duraev  2022-06-18    Red
# 4320            Court McGee  Jeremiah Wells  2022-06-18   Blue
# ...                     ...             ...         ...    ...
# 8589          Chuck Liddell   Vitor Belfort  2002-06-22    Red
# 8593            Jens Pulver         BJ Penn  2002-01-11    Red
# 8594                BJ Penn        Caol Uno  2001-11-02    Red
# 8595          Matt Lindland     Phil Baroni  2001-11-02    Red
# 8596            Jens Pulver  Dennis Hallman  2001-09-28    Red
#
#           weight_class    avg_KD  avg_opp_KD  avg_SUB_ATT  avg_opp_SUB_ATT  \
# 4306       Lightweight  0.000537    0.000000     0.000000         0.000000
# 4308     Featherweight  0.000000    0.000000     0.000000         0.000556
# 4311         Flyweight  0.000000    0.005087     0.002907         0.000727
# 4318      Middleweight  0.000576    0.000266     0.000000         0.000000
# 4320      Welterweight  0.000608    0.000210     0.000837         0.000565
# ...                ...       ...         ...          ...              ...
# 8589  LightHeavyweight  0.000487    0.000000     0.000000         0.000061
# 8593       Lightweight  0.000103    0.000000     0.000488         0.001233
# 8594       Lightweight  0.002179    0.000000     0.000000         0.000000
# 8595      Middleweight  0.000000    0.000000     0.000000         0.000000
# 8596       Lightweight  0.000268    0.000000     0.000201         0.000000
#
#        avg_REV  ...  Stance_Southpaw  Stance_Switch  Stance_nan  \
# 4306  0.000000  ...              0.0            0.0         0.0
# 4308  0.001111  ...              0.0            0.0         0.0
# 4311  0.000000  ...              0.0            0.0         0.0
# 4318  0.000000  ...              1.0            0.0         0.0
# 4320  0.000017  ...              0.0            0.0         0.0
# ...        ...  ...              ...            ...         ...
# 8589  0.000020  ...              0.0            0.0         0.0
# 8593  0.000051  ...              1.0            0.0         0.0
# 8594  0.000000  ...              0.0            0.0         0.0
# 8595  0.000000  ...              1.0            0.0         0.0
# 8596  0.000134  ...              1.0            0.0         0.0
#
#                     fighter  method  fighter_result  cluster  \
# 4306        Arman Tsarukyan   U-DEC   Loss by U-DEC      1.0
# 4308  Shayilan Nuerdanbieke   U-DEC    Win by U-DEC      2.0
# 4311                JP Buys  KO/TKO  Loss by KO/TKO      0.0
# 4318        Joaquin Buckley  KO/TKO   Win by KO/TKO      0.0
# 4320            Court McGee  KO/TKO  Loss by KO/TKO      2.0
# ...                     ...     ...             ...      ...
# 8589          Chuck Liddell   U-DEC    Win by U-DEC      1.0
# 8593            Jens Pulver   M-DEC    Win by M-DEC      0.0
# 8594                BJ Penn  KO/TKO   Win by KO/TKO      1.0
# 8595          Matt Lindland   M-DEC    Win by M-DEC      0.0
# 8596            Jens Pulver   U-DEC    Win by U-DEC      0.0
#
#         specific_cluster  Fighter_dims_y  opp_specific_cluster
# 4306       1_Lightweight  Mateusz Gamrot         0_Lightweight
# 4308     2_Featherweight        TJ Brown       1_Featherweight
# 4311         0_Flyweight     Cody Durden           1_Flyweight
# 4318      0_Middleweight   Albert Duraev        1_Middleweight
# 4320      2_Welterweight  Jeremiah Wells        1_Welterweight
# ...                  ...             ...                   ...
# 8589  1_LightHeavyweight   Vitor Belfort    0_LightHeavyweight
# 8593       0_Lightweight         BJ Penn         1_Lightweight
# 8594       1_Lightweight        Caol Uno         0_Lightweight
# 8595      0_Middleweight     Phil Baroni        1_Middleweight
# 8596       0_Lightweight  Dennis Hallman         1_Lightweight
#
# [1505 rows x 84 columns]

# %%
import pandas as pd

# Assuming your DataFrame is named 'analysis_data_opposing_styles'
# and the columns to combine are 'specific_cluster' and 'opp_specific_cluster'

def create_style_matchup(row):
    # Combine the two columns and sort them alphabetically
    matchup = sorted([row['specific_cluster'], row['opp_specific_cluster']])
    
    # Join them with ' vs. ' and return the result
    return matchup[0] + ' vs. ' + matchup[1]

# Apply the custom function to each row and create the new 'style_matchup' column
analysis_data_opposing_styles['style_matchup'] = analysis_data_opposing_styles.apply(create_style_matchup, axis=1)

# Display the DataFrame
analysis_data_opposing_styles.sort_values(by='weight_class', inplace=True)

# %%
weight_class = list(analysis_data_opposing_styles['weight_class'].drop_duplicates())
weight_class
# Out:
# ['Bantamweight',
#  'Featherweight',
#  'Flyweight',
#  'Heavyweight',
#  'LightHeavyweight',
#  'Lightweight',
#  'Middleweight',
#  'Welterweight',
#  'WomenFlyweight']

# %%
analysis_data_opposing_styles.loc[analysis_data_opposing_styles['style_matchup'] == '0_Lightweight vs. 1_Lightweight']
# Out:
#              R_fighter       B_fighter        date Winner weight_class  \
# 8375     Tyson Griffin   Gleison Tibau  2008-02-02    Red  Lightweight
# 6409        Joe Lauzon      Jim Miller  2016-08-27   Blue  Lightweight
# 8193        Jim Miller      Mac Danzig  2009-07-11    Red  Lightweight
# 8201     Joe Stevenson       Nate Diaz  2009-06-20    Red  Lightweight
# 6770        Stevie Ray  Leonardo Mafra  2015-07-18    Red  Lightweight
# ...                ...             ...         ...    ...          ...
# 6162       Reza Madadi   Joaquim Silva  2017-05-28   Blue  Lightweight
# 6179        Joe Lauzon      Stevie Ray  2017-04-22   Blue  Lightweight
# 6229     Lando Vannata    David Teymur  2017-03-04   Blue  Lightweight
# 6337      Ross Pearson      Stevie Ray  2016-11-19   Blue  Lightweight
# 6353  Rafael Dos Anjos   Tony Ferguson  2016-11-05   Blue  Lightweight
#
#         avg_KD    avg_opp_KD  avg_SUB_ATT  avg_opp_SUB_ATT       avg_REV  ...  \
# 8375  0.000000  0.000000e+00     0.002028         0.003120  6.240250e-04  ...
# 6409  0.001391  2.253706e-04     0.000128         0.000028  1.524417e-04  ...
# 8193  0.000000  0.000000e+00     0.002572         0.000286  2.857959e-04  ...
# 8201  0.000195  2.045802e-04     0.001402         0.001530  8.824427e-04  ...
# 6770  0.000000  0.000000e+00     0.005063         0.000000  0.000000e+00  ...
# ...        ...           ...          ...              ...           ...  ...
# 6162  0.000000  7.575184e-05     0.000189         0.000000  0.000000e+00  ...
# 6179  0.000163  2.649148e-05     0.000995         0.000003  1.791897e-05  ...
# 6229  0.003690  0.000000e+00     0.000000         0.005535  0.000000e+00  ...
# 6337  0.000013  5.690247e-04     0.000000         0.000018  2.136925e-09  ...
# 6353  0.000127  4.752501e-09     0.000118         0.000002  4.752501e-09  ...
#
#       Stance_Switch  Stance_nan           fighter  method  fighter_result  \
# 8375            0.0         0.0     Tyson Griffin   U-DEC    Win by U-DEC
# 6409            0.0         0.0        Joe Lauzon   S-DEC   Loss by S-DEC
# 8193            0.0         0.0        Jim Miller   U-DEC    Win by U-DEC
# 8201            0.0         0.0     Joe Stevenson   U-DEC    Win by U-DEC
# 6770            0.0         0.0        Stevie Ray  KO/TKO   Win by KO/TKO
# ...             ...         ...               ...     ...             ...
# 6162            0.0         0.0       Reza Madadi   S-DEC   Loss by S-DEC
# 6179            0.0         0.0        Joe Lauzon   M-DEC   Loss by M-DEC
# 6229            0.0         0.0     Lando Vannata   U-DEC   Loss by U-DEC
# 6337            0.0         0.0      Ross Pearson   S-DEC   Loss by S-DEC
# 6353            0.0         0.0  Rafael Dos Anjos   U-DEC   Loss by U-DEC
#
#       cluster  specific_cluster  Fighter_dims_y  opp_specific_cluster  \
# 8375      1.0     1_Lightweight   Gleison Tibau         0_Lightweight
# 6409      1.0     1_Lightweight      Jim Miller         0_Lightweight
# 8193      0.0     0_Lightweight      Mac Danzig         1_Lightweight
# 8201      1.0     1_Lightweight       Nate Diaz         0_Lightweight
# 6770      0.0     0_Lightweight  Leonardo Mafra         1_Lightweight
# ...       ...               ...             ...                   ...
# 6162      1.0     1_Lightweight   Joaquim Silva         0_Lightweight
# 6179      1.0     1_Lightweight      Stevie Ray         0_Lightweight
# 6229      1.0     1_Lightweight    David Teymur         0_Lightweight
# 6337      1.0     1_Lightweight      Stevie Ray         0_Lightweight
# 6353      0.0     0_Lightweight   Tony Ferguson         1_Lightweight
#
#                         style_matchup
# 8375  0_Lightweight vs. 1_Lightweight
# 6409  0_Lightweight vs. 1_Lightweight
# 8193  0_Lightweight vs. 1_Lightweight
# 8201  0_Lightweight vs. 1_Lightweight
# 6770  0_Lightweight vs. 1_Lightweight
# ...                               ...
# 6162  0_Lightweight vs. 1_Lightweight
# 6179  0_Lightweight vs. 1_Lightweight
# 6229  0_Lightweight vs. 1_Lightweight
# 6337  0_Lightweight vs. 1_Lightweight
# 6353  0_Lightweight vs. 1_Lightweight
#
# [338 rows x 85 columns]

# %%
from scripts.chisquareanalysis import ChiSquareAnalysis

# Assuming weight_class is a list of weight classes

# Initialize an empty dictionary to store the results
results_dict = {}

for weights in weight_class:
    analysis = ChiSquareAnalysis(df=analysis_data_opposing_styles, category=weights)
    result = analysis.run_chisquare_analysis('fighter_result')
    
    # Save the result in the dictionary with the weight as the key
    # print(weights)
    # print(result)

# Display the results dictionary
# Out:
# Bantamweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                     Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight             1              15
#
# fighter_result                     Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight              4            7              7
#
# fighter_result                     Win by KO/TKO  Win by S-DEC  Win by SUB  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight             14             5          13
#
# fighter_result                     Win by U-DEC
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight            24
# fighter_result                      style_matchup  Draw by DRAW  \
# 0               0_Bantamweight vs. 1_Bantamweight           0.0
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                          0.0            0.0          0.0            0.0
#
# fighter_result  Win by KO/TKO  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                         0.0           0.0         0.0           0.0
# Featherweight
# Chi2 Stat: 21.89650439633363
# P Value: 0.1465648125646093
# Degrees of Freedom: 16
# fighter_result                       Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_Featherweight vs. 1_Featherweight             0               0
# 0_Featherweight vs. 2_Featherweight             0              13
# 1_Featherweight vs. 2_Featherweight             3               6
#
# fighter_result                       Loss by S-DEC  Loss by SUB  \
# style_matchup
# 0_Featherweight vs. 1_Featherweight              0            0
# 0_Featherweight vs. 2_Featherweight              4            3
# 1_Featherweight vs. 2_Featherweight              1            7
#
# fighter_result                       Loss by U-DEC  Win by KO/TKO  \
# style_matchup
# 0_Featherweight vs. 1_Featherweight              1              1
# 0_Featherweight vs. 2_Featherweight             17             12
# 1_Featherweight vs. 2_Featherweight              3              7
#
# fighter_result                       Win by S-DEC  Win by SUB  Win by U-DEC
# style_matchup
# 0_Featherweight vs. 1_Featherweight             0           0             3
# 0_Featherweight vs. 2_Featherweight             5          14            28
# 1_Featherweight vs. 2_Featherweight             4           5            11
# fighter_result                        style_matchup  Draw by DRAW  \
# 0               0_Featherweight vs. 1_Featherweight     -0.318357
# 1               0_Featherweight vs. 2_Featherweight     -1.394972
# 2               1_Featherweight vs. 2_Featherweight      2.097501
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                    -0.801182      -0.410997    -0.581238       0.344940
# 1                     0.192467       0.420210    -1.368936       0.915364
# 2                    -0.013754      -0.466503     2.146034      -1.420726
#
# fighter_result  Win by KO/TKO  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                    0.394558     -0.551411   -0.801182      1.327319
# 1                   -0.270135     -0.346764    0.477319      0.144986
# 2                    0.257381      0.675438   -0.420857     -0.640135
# Flyweight
# Chi2 Stat: 20.184747916762014
# P Value: 0.12442351638659498
# Degrees of Freedom: 14
# fighter_result                Loss by KO/TKO  Loss by S-DEC  Loss by SUB  \
# style_matchup
# -1_Flyweight vs. 0_Flyweight               2              1            1
# -1_Flyweight vs. 1_Flyweight               0              0            0
# 0_Flyweight vs. 1_Flyweight                5              5            5
#
# fighter_result                Loss by U-DEC  Win by KO/TKO  Win by S-DEC  \
# style_matchup
# -1_Flyweight vs. 0_Flyweight              1              5             1
# -1_Flyweight vs. 1_Flyweight              0              2             0
# 0_Flyweight vs. 1_Flyweight              14              5             3
#
# fighter_result                Win by SUB  Win by U-DEC
# style_matchup
# -1_Flyweight vs. 0_Flyweight           1             2
# -1_Flyweight vs. 1_Flyweight           0             0
# 0_Flyweight vs. 1_Flyweight           10            15
# fighter_result                 style_matchup  Loss by KO/TKO  Loss by S-DEC  \
# 0               -1_Flyweight vs. 0_Flyweight        0.663388      -0.074125
# 1               -1_Flyweight vs. 1_Flyweight       -0.423659      -0.392232
# 2                0_Flyweight vs. 1_Flyweight       -0.239145       0.105670
#
# fighter_result  Loss by SUB  Loss by U-DEC  Win by KO/TKO  Win by S-DEC  \
# 0                 -0.074125      -1.031376       1.939327      0.332875
# 1                 -0.392232      -0.620174       3.050851     -0.320256
# 2                  0.105670       0.601487      -1.469500     -0.100660
#
# fighter_result  Win by SUB  Win by U-DEC
# 0                -0.693435     -0.601836
# 1                -0.531085     -0.660225
# 2                 0.424900      0.404567
# Heavyweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                   Draw by DRAW  Loss by DQ  Loss by KO/TKO  \
# style_matchup
# 0_Heavyweight vs. 1_Heavyweight             1           1              19
#
# fighter_result                   Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# style_matchup
# 0_Heavyweight vs. 1_Heavyweight              1              1            1
#
# fighter_result                   Loss by U-DEC  Win by KO/TKO  Win by S-DEC  \
# style_matchup
# 0_Heavyweight vs. 1_Heavyweight              7             24             4
#
# fighter_result                   Win by SUB  Win by U-DEC
# style_matchup
# 0_Heavyweight vs. 1_Heavyweight           7            11
# fighter_result                    style_matchup  Draw by DRAW  Loss by DQ  \
# 0               0_Heavyweight vs. 1_Heavyweight           0.0         0.0
#
# fighter_result  Loss by KO/TKO  Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# 0                          0.0            0.0            0.0          0.0
#
# fighter_result  Loss by U-DEC  Win by KO/TKO  Win by S-DEC  Win by SUB  \
# 0                         0.0            0.0           0.0         0.0
#
# fighter_result  Win by U-DEC
# 0                        0.0
# LightHeavyweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                             Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_LightHeavyweight vs. 1_LightHeavyweight             2              23
#
# fighter_result                             Loss by S-DEC  Loss by SUB  \
# style_matchup
# 0_LightHeavyweight vs. 1_LightHeavyweight              5            9
#
# fighter_result                             Loss by U-DEC  Win by KO/TKO  \
# style_matchup
# 0_LightHeavyweight vs. 1_LightHeavyweight             11             37
#
# fighter_result                             Win by S-DEC  Win by SUB  \
# style_matchup
# 0_LightHeavyweight vs. 1_LightHeavyweight             7          13
#
# fighter_result                             Win by U-DEC
# style_matchup
# 0_LightHeavyweight vs. 1_LightHeavyweight            19
# fighter_result                              style_matchup  Draw by DRAW  \
# 0               0_LightHeavyweight vs. 1_LightHeavyweight           0.0
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                          0.0            0.0          0.0            0.0
#
# fighter_result  Win by KO/TKO  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                         0.0           0.0         0.0           0.0
# Lightweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                   Draw by DRAW  Loss by DQ  Loss by KO/TKO  \
# style_matchup
# 0_Lightweight vs. 1_Lightweight             8           1              27
#
# fighter_result                   Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# style_matchup
# 0_Lightweight vs. 1_Lightweight              1             18           24
#
# fighter_result                   Loss by U-DEC  Win by KO/TKO  Win by M-DEC  \
# style_matchup
# 0_Lightweight vs. 1_Lightweight             49             54             1
#
# fighter_result                   Win by S-DEC  Win by SUB  Win by U-DEC
# style_matchup
# 0_Lightweight vs. 1_Lightweight            21          53            81
# fighter_result                    style_matchup  Draw by DRAW  Loss by DQ  \
# 0               0_Lightweight vs. 1_Lightweight           0.0         0.0
#
# fighter_result  Loss by KO/TKO  Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# 0                          0.0            0.0            0.0          0.0
#
# fighter_result  Loss by U-DEC  Win by KO/TKO  Win by M-DEC  Win by S-DEC  \
# 0                         0.0            0.0           0.0           0.0
#
# fighter_result  Win by SUB  Win by U-DEC
# 0                      0.0           0.0
# Middleweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                     Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_Middleweight vs. 1_Middleweight             6              33
#
# fighter_result                     Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# style_matchup
# 0_Middleweight vs. 1_Middleweight             12           15             25
#
# fighter_result                     Win by DQ  Win by KO/TKO  Win by M-DEC  \
# style_matchup
# 0_Middleweight vs. 1_Middleweight          1             56             1
#
# fighter_result                     Win by S-DEC  Win by SUB  Win by U-DEC
# style_matchup
# 0_Middleweight vs. 1_Middleweight            15          36            55
# fighter_result                      style_matchup  Draw by DRAW  \
# 0               0_Middleweight vs. 1_Middleweight           0.0
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                          0.0            0.0          0.0            0.0
#
# fighter_result  Win by DQ  Win by KO/TKO  Win by M-DEC  Win by S-DEC  \
# 0                     0.0            0.0           0.0           0.0
#
# fighter_result  Win by SUB  Win by U-DEC
# 0                      0.0           0.0
# Welterweight
# Chi2 Stat: 27.401774330738988
# P Value: 0.19636253561547376
# Degrees of Freedom: 22
# fighter_result                     Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_Welterweight vs. 1_Welterweight             0               0
# 0_Welterweight vs. 2_Welterweight             8              30
# 1_Welterweight vs. 2_Welterweight             0               7
#
# fighter_result                     Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# style_matchup
# 0_Welterweight vs. 1_Welterweight              0              2            0
# 0_Welterweight vs. 2_Welterweight              2             14            9
# 1_Welterweight vs. 2_Welterweight              0              0            4
#
# fighter_result                     Loss by U-DEC  Win by DQ  Win by KO/TKO  \
# style_matchup
# 0_Welterweight vs. 1_Welterweight              4          0              4
# 0_Welterweight vs. 2_Welterweight             45          1             45
# 1_Welterweight vs. 2_Welterweight              5          0             10
#
# fighter_result                     Win by M-DEC  Win by S-DEC  Win by SUB  \
# style_matchup
# 0_Welterweight vs. 1_Welterweight             0             4           6
# 0_Welterweight vs. 2_Welterweight             2            20          25
# 1_Welterweight vs. 2_Welterweight             0             1           7
#
# fighter_result                     Win by U-DEC
# style_matchup
# 0_Welterweight vs. 1_Welterweight             4
# 0_Welterweight vs. 2_Welterweight            55
# 1_Welterweight vs. 2_Welterweight            17
# fighter_result                      style_matchup  Draw by DRAW  \
# 0               0_Welterweight vs. 1_Welterweight     -0.761617
# 1               0_Welterweight vs. 2_Welterweight      0.728739
# 2               1_Welterweight vs. 2_Welterweight     -1.110238
#
# fighter_result  Loss by KO/TKO  Loss by M-DEC  Loss by S-DEC  Loss by SUB  \
# 0                    -1.637919      -0.380808       0.779768    -0.970875
# 1                     0.258661       0.364370       0.462049    -0.332522
# 2                     0.544087      -0.555119      -1.570114     1.411012
#
# fighter_result  Loss by U-DEC  Win by DQ  Win by KO/TKO  Win by M-DEC  \
# 0                    0.042751  -0.269272      -0.134382     -0.380808
# 1                    0.500678   0.257648      -0.093473      0.364370
# 2                   -1.151070  -0.392528       0.301607     -0.555119
#
# fighter_result  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                   1.624609    1.954757     -0.643493
# 1                   0.151154   -0.809729     -0.492966
# 2                  -1.453125    0.473204      1.545896
# WomenFlyweight
# Chi2 Stat: 14.408711903564845
# P Value: 0.41972663278748273
# Degrees of Freedom: 14
# fighter_result                          Loss by KO/TKO  Loss by S-DEC  \
# style_matchup
# -1_WomenFlyweight vs. 0_WomenFlyweight               3              0
# -1_WomenFlyweight vs. 1_WomenFlyweight               1              2
# 0_WomenFlyweight vs. 1_WomenFlyweight                1              1
#
# fighter_result                          Loss by SUB  Loss by U-DEC  \
# style_matchup
# -1_WomenFlyweight vs. 0_WomenFlyweight            1              1
# -1_WomenFlyweight vs. 1_WomenFlyweight            2              3
# 0_WomenFlyweight vs. 1_WomenFlyweight             2              9
#
# fighter_result                          Win by KO/TKO  Win by S-DEC  \
# style_matchup
# -1_WomenFlyweight vs. 0_WomenFlyweight              3             0
# -1_WomenFlyweight vs. 1_WomenFlyweight              2             0
# 0_WomenFlyweight vs. 1_WomenFlyweight               5             3
#
# fighter_result                          Win by SUB  Win by U-DEC
# style_matchup
# -1_WomenFlyweight vs. 0_WomenFlyweight           2             2
# -1_WomenFlyweight vs. 1_WomenFlyweight           3             3
# 0_WomenFlyweight vs. 1_WomenFlyweight            4             9
# fighter_result                           style_matchup  Loss by KO/TKO  \
# 0               -1_WomenFlyweight vs. 0_WomenFlyweight        2.065851
# 1               -1_WomenFlyweight vs. 1_WomenFlyweight       -0.255583
# 2                0_WomenFlyweight vs. 1_WomenFlyweight       -1.051970
#
# fighter_result  Loss by S-DEC  Loss by SUB  Loss by U-DEC  Win by KO/TKO  \
# 0                   -0.762001     0.032791      -0.955806       0.765169
# 1                    1.393148     0.624758      -0.193729      -0.361449
# 2                   -0.502995    -0.448061       0.700730      -0.206626
#
# fighter_result  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                  -0.762001    0.195529     -0.431124
# 1                  -0.879883    0.444500     -0.322451
# 2                   1.056290   -0.421087      0.477325

# %%
fighter_result = list(analysis_data_opposing_styles['fighter_result'].drop_duplicates())

# %%
from scripts.chisquareanalysis import ChiSquareAnalysis
analysis = ChiSquareAnalysis(df=analysis_data_opposing_styles, category='Bantamweight')
result_batamweight = analysis.run_chisquare_analysis('fighter_result')
result_batamweight
# Out:
# Bantamweight
# Chi2 Stat: 0.0
# P Value: 1.0
# Degrees of Freedom: 0
# fighter_result                     Draw by DRAW  Loss by KO/TKO  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight             1              15
#
# fighter_result                     Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight              4            7              7
#
# fighter_result                     Win by KO/TKO  Win by S-DEC  Win by SUB  \
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight             14             5          13
#
# fighter_result                     Win by U-DEC
# style_matchup
# 0_Bantamweight vs. 1_Bantamweight            24
# fighter_result                      style_matchup  Draw by DRAW  \
# 0               0_Bantamweight vs. 1_Bantamweight           0.0
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                          0.0            0.0          0.0            0.0
#
# fighter_result  Win by KO/TKO  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                         0.0           0.0         0.0           0.0
# fighter_result                      style_matchup  Draw by DRAW  \
# 0               0_Bantamweight vs. 1_Bantamweight           0.0
#
# fighter_result  Loss by KO/TKO  Loss by S-DEC  Loss by SUB  Loss by U-DEC  \
# 0                          0.0            0.0          0.0            0.0
#
# fighter_result  Win by KO/TKO  Win by S-DEC  Win by SUB  Win by U-DEC
# 0                         0.0           0.0         0.0           0.0

# %%
import seaborn as sns
import matplotlib as plt 

esult_batamweight_col = result_batamweight.drop(columns=['style_matchup']).columns

# Prepare the data for the heatmap
heatmap_data = result_batamweight.set_index('style_matchup')[result_batamweight_col]

# Create the heatmap
plt.figure(figsize=(8, 4))
sns.heatmap(heatmap_data, cmap='coolwarm', annot=True, linewidths=0.5, center=0)
plt.title('Fight Result by Style: Batamweight')
plt.xlabel('Result')
plt.ylabel('Style Matchup')
#plt.savefig(r"C:\Users\johna\anaconda3\envs\twitter-influence-env\twitter-influence\data\03_reports\sentiment_heatmap.png")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[11], line 7
#       4 esult_batamweight_col = result_batamweight.drop(columns=['style_matchup']).columns
#       6 # Prepare the data for the heatmap
# ----> 7 heatmap_data = result_batamweight.set_index('style_matchup')[result_batamweight_col]
#       9 # Create the heatmap
#      10 plt.figure(figsize=(8, 4))
#
# NameError: name 'result_batamweight_col' is not defined

# %%
import requests
import json
# import style dims
url = 'https://github.com/john-adeojo/ufc_styles/raw/main/data/02_intermediate/style_dims_names.json'

# Fetch the JSON file content
response = requests.get(url)

# Check if the request was successful (HTTP status code 200)
if response.status_code == 200:
    try:
        # Load the content into a list
        style_dims_names = json.loads(response.text)
        print("Data loaded successfully:")
    except json.JSONDecodeError as e:
        print(f"Failed to decode JSON: {e}")
else:
    print(f"Failed to fetch JSON file: {response.status_code}")

# %%
style_dims_names_2 = style_dims_names
style_dims_names_2.append('specific_cluster')

# %%
selected_clusters = ['0_Bantamweight', '1_Bantamweight', '2_Bantamweight']
filtered_data = all_fighter_cluster[all_fighter_cluster['specific_cluster'].isin(selected_clusters)]
analytics_for_radar = filtered_data[style_dims_names_2].groupby(['specific_cluster']).mean()
analytics_for_radar.reset_index(inplace=True)
analytics_for_radar

# %%
analytics_for_radar.info()

# %%
import plotly.graph_objects as go
import pandas as pd

# Replace this with your actual dataframe
# analytics_for_radar = ...

# Select dimensions to plot
selected_dimensions = analytics_for_radar.drop(columns='specific_cluster').columns

def plot_fighters_radar_chart(data=analytics_for_radar, dimensions=selected_dimensions):
    fig = go.Figure()

    for specific_cluster in data['specific_cluster'].unique():
        cluster_data = data[data['specific_cluster'] == specific_cluster]

        fig.add_trace(go.Scatterpolar(
            r=cluster_data[dimensions].values.tolist()[0],
            theta=dimensions,
            fill='toself',
            name=specific_cluster,
            opacity=0.5,
            line=dict(width=0.8)
        ))

    fig.update_layout(
        polar=dict(
            radialaxis=dict(
                visible=True,
                range=[0, data[dimensions].values.astype(float).max()]  # Set the range based on the maximum value in the data
            ),
            angularaxis=dict(
                rotation=90,
                direction="counterclockwise"
            ),
        ),
        showlegend=True,
        width=1400,
        height=1000
    )

    fig.show()

plot_fighters_radar_chart()
